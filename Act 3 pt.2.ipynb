# %% [markdown]
# Activity 3 part 2

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("datasets/adult.csv")
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32564.000000  3.256400e+04   32564.000000  32564.000000  32564.000000
# mean      38.582883  1.897874e+05      10.080580   1078.933669     87.295787
# std       13.640412  1.055493e+05       2.572623   7386.164888    402.942527
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783765e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370682e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32564.000000
# mean        40.437416
# std         12.346861
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
pd.pivot_table(df,
               index='marital-status',
               aggfunc='count',
               margins=True
              )
# Out:
#                           age  capital-gain  capital-loss  education  \
# marital-status
#  Divorced                4443          4443          4443       4443
#  Married-AF-spouse         23            23            23         23
#  Married-civ-spouse     14976         14976         14976      14976
#  Married-spouse-absent    418           418           418        418
#  Never-married          10683         10683         10683      10683
#  Separated               1025          1025          1025       1025
#  Widowed                  993           993           993        993
#  test_category_female       1             1             1          1
#  test_category_male         2             2             2          2
# All                     32564         32564         32564      32564
#
#                         education-num  fnlwgt  hours-per-week  native-country  \
# marital-status
#  Divorced                        4443    4443            4443            4443
# ...

# %%
pd.pivot_table(df,
               index='marital-status',
               aggfunc='',
               margins=True
              )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_104/1588766585.py in <module>
#       2                index='marital-status',
#       3                aggfunc='%',
# ----> 4                margins=True
#       5               )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      99
#     100     grouped = data.groupby(keys, observed=observed)
# --> 101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     103         agged = agged.dropna(how="all")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     926         func = _maybe_mangle_lambdas(func)
#     927
# ...
